# %%
#import the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_api_key

import time
from scipy.stats import linregress

# %%
#Create random lats and lngs using numpy and random 
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000 )
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000 )
lat_lngs = zip(lats,lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?lat=57&lon=-2.15&appid=" + weather_api_key + "&units=imperial"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        #Parse the JSON and retreive data
        city_weather = requests.get(city_url).json()
        
        #Parse out needing data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        
        #append the data into city_data list
        
        city_data.append({
            "City": city.title(),
            "Country" : city_country,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description": city_description
        }
        )
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | xuanhua
# Processing Record 2 of Set 1 | riyadh
# Processing Record 3 of Set 1 | craig
# Processing Record 4 of Set 1 | kindu
# Processing Record 5 of Set 1 | kismayo
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | filingue
# Processing Record 13 of Set 1 | kavieng
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | paamiut
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | santa maria del oro
# Processing Record 18 of Set 1 | bow island
# Processing Record 19 of Set 1 | poum
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | la ronge
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | vila velha
# Processing Record 27 of Set 1 | zhigansk
# Processing Record 28 of Set 1 | saint-jean-port-joli
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | huasahuasi
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 1 | jacmel
# Processing Record 35 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 1 | amahai
# Processing Record 37 of Set 1 | marsh harbour
# Processing Record 38 of Set 1 | vila
# Processing Record 39 of Set 1 | mvuma
# Processing Record 40 of Set 1 | somerset west
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | henties bay
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | port hardy
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | vao
# Processing Record 50 of Set 1 | vilhena
# Processing Record 1 of Set 2 | bontang
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | chifeng
# Processing Record 4 of Set 2 | crixas
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | goundam
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | hovd
# Processing Record 12 of Set 2 | akle
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | porto novo
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | egvekinot
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | mildura
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | korbach
# Processing Record 22 of Set 2 | saeby
# Processing Record 23 of Set 2 | kuching
# Processing Record 24 of Set 2 | kirakira
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | guane
# Processing Record 28 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | cockburn town
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | rzeszow
# Processing Record 33 of Set 2 | rocha
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | nome
# Processing Record 36 of Set 2 | tirukkoyilur
# Processing Record 37 of Set 2 | jalu
# Processing Record 38 of Set 2 | lata
# Processing Record 39 of Set 2 | jian
# Processing Record 40 of Set 2 | margate
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | tazmalt
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | kallifonion
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | mayo
# Processing Record 50 of Set 2 | mount isa
# Processing Record 1 of Set 3 | alice springs
# Processing Record 2 of Set 3 | yar-sale
# Processing Record 3 of Set 3 | nuristan
# Processing Record 4 of Set 3 | volot
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | george
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | darhan
# Processing Record 9 of Set 3 | tautira
# Processing Record 10 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 3 | mandiana
# Processing Record 12 of Set 3 | preobrazheniye
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | kijang
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | gander
# Processing Record 18 of Set 3 | aquiraz
# Processing Record 19 of Set 3 | srednekolymsk
# Processing Record 20 of Set 3 | chiang rai
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | banda aceh
# Processing Record 23 of Set 3 | krasnoselkup
# Processing Record 24 of Set 3 | salalah
# Processing Record 25 of Set 3 | porosozero
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | taksimo
# Processing Record 29 of Set 3 | sompeta
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | richards bay
# Processing Record 32 of Set 3 | dangara
# Processing Record 33 of Set 3 | charters towers
# Processing Record 34 of Set 3 | yumen
# Processing Record 35 of Set 3 | sao filipe
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | dalinghe
# City not found. Skipping...
# Processing Record 38 of Set 3 | yerbogachen
# Processing Record 39 of Set 3 | parati
# Processing Record 40 of Set 3 | sharan
# Processing Record 41 of Set 3 | panama city
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 3 | savannakhet
# Processing Record 45 of Set 3 | grand gaube
# Processing Record 46 of Set 3 | yizheng
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | asau
# Processing Record 49 of Set 3 | hambantota
# Processing Record 50 of Set 3 | atuona
# Processing Record 1 of Set 4 | kusti
# Processing Record 2 of Set 4 | san ignacio
# Processing Record 3 of Set 4 | seymchan
# Processing Record 4 of Set 4 | huaraz
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | new norfolk
# Processing Record 7 of Set 4 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 8 of Set 4 | williams lake
# Processing Record 9 of Set 4 | letlhakeng
# Processing Record 10 of Set 4 | rundu
# Processing Record 11 of Set 4 | saint-augustin
# Processing Record 12 of Set 4 | quatre cocos
# Processing Record 13 of Set 4 | mahibadhoo
# Processing Record 14 of Set 4 | mataura
# Processing Record 15 of Set 4 | sarkand
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | mugan
# Processing Record 18 of Set 4 | bakchar
# Processing Record 19 of Set 4 | saint-francois
# Processing Record 20 of Set 4 | batagay-alyta
# Processing Record 21 of Set 4 | florence
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | aranos
# Processing Record 24 of Set 4 | terenos
# Processing Record 25 of Set 4 | dong xoai
# Processing Record 26 of Set 4 | khandyga
# Processing Record 27 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 4 | kendari
# Processing Record 30 of Set 4 | cap malheureux
# Processing Record 31 of Set 4 | alugan
# Processing Record 32 of Set 4 | luoyang
# Processing Record 33 of Set 4 | baghdad
# Processing Record 34 of Set 4 | kaukauna
# Processing Record 35 of Set 4 | north platte
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | biak
# Processing Record 38 of Set 4 | kruisfontein
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | jhanjharpur
# Processing Record 41 of Set 4 | santa rosa
# Processing Record 42 of Set 4 | lookan
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | sabinas hidalgo
# Processing Record 46 of Set 4 | westport
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | sindor
# Processing Record 49 of Set 4 | tilichiki
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | te anau
# Processing Record 2 of Set 5 | gilbues
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | vostok
# Processing Record 6 of Set 5 | thompson
# Processing Record 7 of Set 5 | jiamusi
# Processing Record 8 of Set 5 | forrest city
# Processing Record 9 of Set 5 | huarmey
# Processing Record 10 of Set 5 | banbury
# Processing Record 11 of Set 5 | skibbereen
# Processing Record 12 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 5 | pafos
# Processing Record 14 of Set 5 | bitung
# Processing Record 15 of Set 5 | half moon bay
# Processing Record 16 of Set 5 | urumqi
# Processing Record 17 of Set 5 | viedma
# Processing Record 18 of Set 5 | emerald
# Processing Record 19 of Set 5 | namatanai
# Processing Record 20 of Set 5 | tongling
# Processing Record 21 of Set 5 | tekirdag
# Processing Record 22 of Set 5 | paraiso
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | guanica
# Processing Record 25 of Set 5 | chuy
# Processing Record 26 of Set 5 | vaitape
# Processing Record 27 of Set 5 | miles city
# Processing Record 28 of Set 5 | gimli
# Processing Record 29 of Set 5 | irricana
# Processing Record 30 of Set 5 | walvis bay
# Processing Record 31 of Set 5 | mezen
# Processing Record 32 of Set 5 | horta
# Processing Record 33 of Set 5 | laguna
# Processing Record 34 of Set 5 | porbandar
# Processing Record 35 of Set 5 | corn island
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | nivala
# Processing Record 38 of Set 5 | najran
# Processing Record 39 of Set 5 | rio cauto
# Processing Record 40 of Set 5 | watsa
# Processing Record 41 of Set 5 | haines junction
# Processing Record 42 of Set 5 | lastoursville
# Processing Record 43 of Set 5 | baracoa
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 5 | nuuk
# Processing Record 47 of Set 5 | deniliquin
# Processing Record 48 of Set 5 | dunedin
# Processing Record 49 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 5 | beloha
# Processing Record 1 of Set 6 | ramet
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | hay river
# Processing Record 4 of Set 6 | jalingo
# Processing Record 5 of Set 6 | mitchell
# Processing Record 6 of Set 6 | grindavik
# Processing Record 7 of Set 6 | qaanaaq
# Processing Record 8 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | torrington
# Processing Record 13 of Set 6 | kamen-rybolov
# Processing Record 14 of Set 6 | hithadhoo
# Processing Record 15 of Set 6 | faya
# Processing Record 16 of Set 6 | gat
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | klaksvik
# Processing Record 19 of Set 6 | twentynine palms
# Processing Record 20 of Set 6 | luancheng
# Processing Record 21 of Set 6 | da nang
# Processing Record 22 of Set 6 | storforshei
# Processing Record 23 of Set 6 | lewisporte
# Processing Record 24 of Set 6 | mitsamiouli
# Processing Record 25 of Set 6 | bozoum
# Processing Record 26 of Set 6 | port macquarie
# Processing Record 27 of Set 6 | ucluelet
# Processing Record 28 of Set 6 | mariakani
# Processing Record 29 of Set 6 | altagracia de orituco
# Processing Record 30 of Set 6 | champasak
# Processing Record 31 of Set 6 | luba
# Processing Record 32 of Set 6 | methoni
# Processing Record 33 of Set 6 | tazovskiy
# Processing Record 34 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 6 | sangin
# Processing Record 36 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 6 | dzhebariki-khaya
# Processing Record 39 of Set 6 | patacamaya
# Processing Record 40 of Set 6 | cap-aux-meules
# Processing Record 41 of Set 6 | rio gallegos
# Processing Record 42 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 43 of Set 6 | bireun
# Processing Record 44 of Set 6 | coihaique
# Processing Record 45 of Set 6 | rapid valley
# Processing Record 46 of Set 6 | agva
# City not found. Skipping...
# Processing Record 47 of Set 6 | ziarat
# Processing Record 48 of Set 6 | ellsworth
# Processing Record 49 of Set 6 | harper
# Processing Record 50 of Set 6 | lavrentiya
# Processing Record 1 of Set 7 | ibra
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | esperance
# Processing Record 4 of Set 7 | bumba
# Processing Record 5 of Set 7 | aripuana
# Processing Record 6 of Set 7 | maningrida
# Processing Record 7 of Set 7 | college
# Processing Record 8 of Set 7 | halifax
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | barao de melgaco
# Processing Record 11 of Set 7 | yulara
# Processing Record 12 of Set 7 | jumla
# Processing Record 13 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 7 | blagoveshchenka
# Processing Record 15 of Set 7 | sur
# Processing Record 16 of Set 7 | parkes
# Processing Record 17 of Set 7 | sorland
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | karratha
# Processing Record 20 of Set 7 | kodinar
# Processing Record 21 of Set 7 | giyon
# Processing Record 22 of Set 7 | tambacounda
# Processing Record 23 of Set 7 | maxixe
# Processing Record 24 of Set 7 | ballina
# Processing Record 25 of Set 7 | lunca
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | ambulu
# Processing Record 28 of Set 7 | voi
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | tessalit
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | maldonado
# Processing Record 33 of Set 7 | sargur
# Processing Record 34 of Set 7 | lakes entrance
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | lazaro cardenas
# Processing Record 37 of Set 7 | fort myers
# Processing Record 38 of Set 7 | abu samrah
# Processing Record 39 of Set 7 | marystown
# Processing Record 40 of Set 7 | donauworth
# Processing Record 41 of Set 7 | ringsted
# Processing Record 42 of Set 7 | amapa
# Processing Record 43 of Set 7 | baruun-urt
# Processing Record 44 of Set 7 | arlit
# Processing Record 45 of Set 7 | jishou
# Processing Record 46 of Set 7 | treinta y tres
# Processing Record 47 of Set 7 | eureka
# Processing Record 48 of Set 7 | shuangcheng
# Processing Record 49 of Set 7 | carnarvon
# Processing Record 50 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | aksarka
# Processing Record 2 of Set 8 | chaochou
# City not found. Skipping...
# Processing Record 3 of Set 8 | tigzirt
# Processing Record 4 of Set 8 | guerrero negro
# Processing Record 5 of Set 8 | bulawayo
# Processing Record 6 of Set 8 | vagur
# Processing Record 7 of Set 8 | sironj
# Processing Record 8 of Set 8 | sibay
# Processing Record 9 of Set 8 | almaznyy
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | san patricio
# Processing Record 12 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 8 | gushikawa
# Processing Record 14 of Set 8 | hualmay
# Processing Record 15 of Set 8 | taoudenni
# Processing Record 16 of Set 8 | la palma
# Processing Record 17 of Set 8 | topolobampo
# Processing Record 18 of Set 8 | neustrelitz
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | yershov
# Processing Record 21 of Set 8 | khatanga
# Processing Record 22 of Set 8 | adrasmon
# Processing Record 23 of Set 8 | carmo do rio claro
# Processing Record 24 of Set 8 | souillac
# Processing Record 25 of Set 8 | cartagena
# Processing Record 26 of Set 8 | duz
# City not found. Skipping...
# Processing Record 27 of Set 8 | elko
# Processing Record 28 of Set 8 | plettenberg bay
# Processing Record 29 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | ambilobe
# Processing Record 31 of Set 8 | berdigestyakh
# Processing Record 32 of Set 8 | kocevje
# Processing Record 33 of Set 8 | centenario do sul
# Processing Record 34 of Set 8 | laiwu
# Processing Record 35 of Set 8 | miraflores
# Processing Record 36 of Set 8 | el campo
# Processing Record 37 of Set 8 | nyurba
# Processing Record 38 of Set 8 | gamba
# Processing Record 39 of Set 8 | praia
# Processing Record 40 of Set 8 | santa maria da vitoria
# Processing Record 41 of Set 8 | puerto leguizamo
# Processing Record 42 of Set 8 | kitami
# Processing Record 43 of Set 8 | kamensk-uralskiy
# Processing Record 44 of Set 8 | karasuk
# Processing Record 45 of Set 8 | chapais
# Processing Record 46 of Set 8 | havelock
# Processing Record 47 of Set 8 | mayumba
# Processing Record 48 of Set 8 | sao joao da barra
# Processing Record 49 of Set 8 | tuatapere
# Processing Record 50 of Set 8 | atambua
# Processing Record 1 of Set 9 | malindi
# Processing Record 2 of Set 9 | the valley
# Processing Record 3 of Set 9 | sakakah
# Processing Record 4 of Set 9 | nevsehir
# Processing Record 5 of Set 9 | kasongo-lunda
# Processing Record 6 of Set 9 | adrar
# Processing Record 7 of Set 9 | pervomayskiy
# Processing Record 8 of Set 9 | benguela
# Processing Record 9 of Set 9 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 10 of Set 9 | wyndham
# Processing Record 11 of Set 9 | santa isabel do rio negro
# Processing Record 12 of Set 9 | samarai
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | kyaikkami
# Processing Record 15 of Set 9 | beringovskiy
# Processing Record 16 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 9 | sal rei
# Processing Record 18 of Set 9 | mardin
# Processing Record 19 of Set 9 | komsomolskiy
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | lipari
# Processing Record 22 of Set 9 | toowoomba
# Processing Record 23 of Set 9 | celestun
# Processing Record 24 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 9 | kupang
# Processing Record 26 of Set 9 | mamaku
# Processing Record 27 of Set 9 | yenagoa
# Processing Record 28 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 9 | mahajanga
# Processing Record 30 of Set 9 | evensk
# Processing Record 31 of Set 9 | springbok
# Processing Record 32 of Set 9 | tondon
# Processing Record 33 of Set 9 | praia da vitoria
# Processing Record 34 of Set 9 | brokopondo
# Processing Record 35 of Set 9 | mount gambier
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | turukhansk
# Processing Record 38 of Set 9 | wanaka
# Processing Record 39 of Set 9 | manzanillo
# Processing Record 40 of Set 9 | ardmore
# Processing Record 41 of Set 9 | espanola
# Processing Record 42 of Set 9 | zaranj
# Processing Record 43 of Set 9 | lubbock
# Processing Record 44 of Set 9 | bereznik
# Processing Record 45 of Set 9 | warrnambool
# Processing Record 46 of Set 9 | butembo
# Processing Record 47 of Set 9 | kenai
# Processing Record 48 of Set 9 | zwedru
# Processing Record 49 of Set 9 | jiazi
# Processing Record 50 of Set 9 | mokhsogollokh
# Processing Record 1 of Set 10 | argayash
# Processing Record 2 of Set 10 | hofn
# Processing Record 3 of Set 10 | saint-pierre
# Processing Record 4 of Set 10 | nishihara
# Processing Record 5 of Set 10 | mazatlan
# Processing Record 6 of Set 10 | malakal
# Processing Record 7 of Set 10 | cherskiy
# Processing Record 8 of Set 10 | steamboat springs
# Processing Record 9 of Set 10 | kabompo
# Processing Record 10 of Set 10 | prieska
# Processing Record 11 of Set 10 | bauchi
# Processing Record 12 of Set 10 | raurkela
# City not found. Skipping...
# Processing Record 13 of Set 10 | santa maria
# Processing Record 14 of Set 10 | fortuna
# Processing Record 15 of Set 10 | manama
# Processing Record 16 of Set 10 | rong kwang
# Processing Record 17 of Set 10 | tocopilla
# Processing Record 18 of Set 10 | sola
# Processing Record 19 of Set 10 | safaga
# Processing Record 20 of Set 10 | dalbandin
# Processing Record 21 of Set 10 | cayenne
# Processing Record 22 of Set 10 | dalby
# Processing Record 23 of Set 10 | sitka
# Processing Record 24 of Set 10 | san juan
# Processing Record 25 of Set 10 | chernyshevskiy
# Processing Record 26 of Set 10 | dicabisagan
# Processing Record 27 of Set 10 | shimoda
# Processing Record 28 of Set 10 | lincoln
# Processing Record 29 of Set 10 | port augusta
# Processing Record 30 of Set 10 | waingapu
# Processing Record 31 of Set 10 | abha
# Processing Record 32 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 10 | khandbari
# Processing Record 34 of Set 10 | kazerun
# Processing Record 35 of Set 10 | numan
# Processing Record 36 of Set 10 | idrinskoye
# Processing Record 37 of Set 10 | airai
# Processing Record 38 of Set 10 | narsaq
# Processing Record 39 of Set 10 | ramsar
# Processing Record 40 of Set 10 | imbituba
# Processing Record 41 of Set 10 | gigmoto
# Processing Record 42 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 10 | cabo san lucas
# Processing Record 44 of Set 10 | wanning
# Processing Record 45 of Set 10 | cadiz
# Processing Record 46 of Set 10 | jedburgh
# Processing Record 47 of Set 10 | bangangte
# Processing Record 48 of Set 10 | camacha
# Processing Record 49 of Set 10 | kavaratti
# Processing Record 50 of Set 10 | ondal
# City not found. Skipping...
# Processing Record 1 of Set 11 | lufilufi
# Processing Record 2 of Set 11 | saint-leu
# Processing Record 3 of Set 11 | kegalla
# City not found. Skipping...
# Processing Record 4 of Set 11 | xam nua
# Processing Record 5 of Set 11 | syumsi
# Processing Record 6 of Set 11 | teguise
# Processing Record 7 of Set 11 | caravelas
# Processing Record 8 of Set 11 | sovetskiy
# Processing Record 9 of Set 11 | hargeysa
# Processing Record 10 of Set 11 | avera
# Processing Record 11 of Set 11 | mansa
# Processing Record 12 of Set 11 | santander
# Processing Record 13 of Set 11 | sambava
# Processing Record 14 of Set 11 | punta de piedra
# Processing Record 15 of Set 11 | manresa
# Processing Record 16 of Set 11 | arman
# Processing Record 17 of Set 11 | kushima
# Processing Record 18 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 11 | los algarrobos
# Processing Record 20 of Set 11 | raudeberg
# Processing Record 21 of Set 11 | kahului
# Processing Record 22 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 23 of Set 11 | wakema
# Processing Record 24 of Set 11 | winnemucca
# Processing Record 25 of Set 11 | huicheng
# Processing Record 26 of Set 11 | palera
# Processing Record 27 of Set 11 | bambous virieux
# Processing Record 28 of Set 11 | sao jose da coroa grande
# Processing Record 29 of Set 11 | marsa matruh
# Processing Record 30 of Set 11 | grenaa
# Processing Record 31 of Set 11 | rio grande
# Processing Record 32 of Set 11 | atherton
# Processing Record 33 of Set 11 | port keats
# Processing Record 34 of Set 11 | mahina
# Processing Record 35 of Set 11 | teya
# Processing Record 36 of Set 11 | cao bang
# Processing Record 37 of Set 11 | sajanan
# Processing Record 38 of Set 11 | esso
# Processing Record 39 of Set 11 | ronneby
# Processing Record 40 of Set 11 | gberia fotombu
# Processing Record 41 of Set 11 | tortoli
# Processing Record 42 of Set 11 | zyryanka
# Processing Record 43 of Set 11 | lahij
# Processing Record 44 of Set 11 | concepcion del oro
# Processing Record 45 of Set 11 | lashio
# Processing Record 46 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | fort nelson
# Processing Record 48 of Set 11 | kibre mengist
# Processing Record 49 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 50 of Set 11 | qaqortoq
# Processing Record 1 of Set 12 | korla
# Processing Record 2 of Set 12 | taitung
# Processing Record 3 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 12 | belmonte
# Processing Record 5 of Set 12 | grand forks
# Processing Record 6 of Set 12 | compostela
# Processing Record 7 of Set 12 | balkhash
# Processing Record 8 of Set 12 | syamzha
# Processing Record 9 of Set 12 | camacupa
# Processing Record 10 of Set 12 | aswan
# Processing Record 11 of Set 12 | broome
# Processing Record 12 of Set 12 | kontagora
# Processing Record 13 of Set 12 | kormilovka
# Processing Record 14 of Set 12 | atlantic beach
# Processing Record 15 of Set 12 | aklavik
# Processing Record 16 of Set 12 | mapimi
# Processing Record 17 of Set 12 | den helder
# Processing Record 18 of Set 12 | huercal-overa
# Processing Record 19 of Set 12 | byron bay
# Processing Record 20 of Set 12 | kaeo
# Processing Record 21 of Set 12 | wick
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | svencionys
# Processing Record 24 of Set 12 | zaokskiy
# Processing Record 25 of Set 12 | touho
# Processing Record 26 of Set 12 | bugiri
# Processing Record 27 of Set 12 | sychevka
# Processing Record 28 of Set 12 | road town
# Processing Record 29 of Set 12 | pozo colorado
# Processing Record 30 of Set 12 | nanortalik
# Processing Record 31 of Set 12 | beatrice
# Processing Record 32 of Set 12 | livingston
# Processing Record 33 of Set 12 | lukovetskiy
# Processing Record 34 of Set 12 | santa marinella
# Processing Record 35 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 36 of Set 12 | okha
# Processing Record 37 of Set 12 | garowe
# Processing Record 38 of Set 12 | khunti
# Processing Record 39 of Set 12 | brae
# Processing Record 40 of Set 12 | valea marului
# City not found. Skipping...
# Processing Record 41 of Set 12 | coria
# Processing Record 42 of Set 12 | turayf
# Processing Record 43 of Set 12 | cedar city
# Processing Record 44 of Set 12 | pleasanton
# Processing Record 45 of Set 12 | coquimbo
# Processing Record 46 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 12 | skala
# Processing Record 48 of Set 12 | pacific grove
# Processing Record 49 of Set 12 | hami
# Processing Record 50 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 13 | seara
# Processing Record 2 of Set 13 | abancay
# Processing Record 3 of Set 13 | muros
# Processing Record 4 of Set 13 | lethem
# Processing Record 5 of Set 13 | nouadhibou
# Processing Record 6 of Set 13 | naze
# Processing Record 7 of Set 13 | shenjiamen
# Processing Record 8 of Set 13 | matehuala
# Processing Record 9 of Set 13 | tutoia
# Processing Record 10 of Set 13 | shelburne
# Processing Record 11 of Set 13 | conakry
# Processing Record 12 of Set 13 | itarema
# Processing Record 13 of Set 13 | ikom
# Processing Record 14 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 13 | algiers
# Processing Record 16 of Set 13 | phan thiet
# Processing Record 17 of Set 13 | unye
# City not found. Skipping...
# Processing Record 18 of Set 13 | itatiaia
# Processing Record 19 of Set 13 | san cristobal
# Processing Record 20 of Set 13 | pratapgarh
# Processing Record 21 of Set 13 | colac
# Processing Record 22 of Set 13 | san andres
# Processing Record 23 of Set 13 | acarau
# Processing Record 24 of Set 13 | saint anthony
# Processing Record 25 of Set 13 | norrtalje
# Processing Record 26 of Set 13 | beyneu
# Processing Record 27 of Set 13 | lasa
# Processing Record 28 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 13 | ouesso
# Processing Record 30 of Set 13 | puerto del rosario
# Processing Record 31 of Set 13 | yabrud
# Processing Record 32 of Set 13 | kununurra
# Processing Record 33 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | tromso
# Processing Record 35 of Set 13 | sembe
# Processing Record 36 of Set 13 | bayanday
# Processing Record 37 of Set 13 | takoradi
# Processing Record 38 of Set 13 | burnie
# Processing Record 39 of Set 13 | vila franca do campo
# Processing Record 40 of Set 13 | san isidro
# Processing Record 41 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 13 | comodoro rivadavia
# Processing Record 43 of Set 13 | athabasca
# Processing Record 44 of Set 13 | puerto montt
# Processing Record 45 of Set 13 | lalibela
# Processing Record 46 of Set 13 | osakarovka
# Processing Record 47 of Set 13 | nemuro
# Processing Record 48 of Set 13 | jan kempdorp
# Processing Record 49 of Set 13 | dapdap
# Processing Record 50 of Set 13 | mandalgovi
# Processing Record 1 of Set 14 | dryden
# Processing Record 2 of Set 14 | bignona
# Processing Record 3 of Set 14 | los llanos de aridane
# Processing Record 4 of Set 14 | mednogorsk
# Processing Record 5 of Set 14 | maceio
# Processing Record 6 of Set 14 | nantucket
# Processing Record 7 of Set 14 | puerto madryn
# Processing Record 8 of Set 14 | helmsdale
# Processing Record 9 of Set 14 | itaueira
# Processing Record 10 of Set 14 | pangnirtung
# Processing Record 11 of Set 14 | carinhanha
# Processing Record 12 of Set 14 | san-pedro
# Processing Record 13 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 14 | cururupu
# Processing Record 15 of Set 14 | olafsvik
# Processing Record 16 of Set 14 | charlestown
# Processing Record 17 of Set 14 | douglas
# Processing Record 18 of Set 14 | morondava
# Processing Record 19 of Set 14 | bocaiuva
# Processing Record 20 of Set 14 | makakilo city
# Processing Record 21 of Set 14 | homer
# Processing Record 22 of Set 14 | pangody
# Processing Record 23 of Set 14 | el higo
# Processing Record 24 of Set 14 | puerto narino
# Processing Record 25 of Set 14 | wiwili
# Processing Record 26 of Set 14 | mangai
# Processing Record 27 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 14 | shar
# Processing Record 29 of Set 14 | balkanabat
# Processing Record 30 of Set 14 | kedrovyy
# Processing Record 31 of Set 14 | thilogne
# City not found. Skipping...
# Processing Record 32 of Set 14 | mogzon
# Processing Record 33 of Set 14 | kota kinabalu
# Processing Record 34 of Set 14 | necochea
# Processing Record 35 of Set 14 | kastamonu
# Processing Record 36 of Set 14 | aksha
# Processing Record 37 of Set 14 | siguiri
# Processing Record 38 of Set 14 | lewiston
# Processing Record 39 of Set 14 | padang
# Processing Record 40 of Set 14 | labuhan
# Processing Record 41 of Set 14 | coos bay
# Processing Record 42 of Set 14 | zaoyang
# Processing Record 43 of Set 14 | bat khela
# Processing Record 44 of Set 14 | malibu
# Processing Record 45 of Set 14 | duluth
# Processing Record 46 of Set 14 | wanxian
# Processing Record 47 of Set 14 | gisborne
# Processing Record 48 of Set 14 | khorixas
# Processing Record 49 of Set 14 | ust-tsilma
# Processing Record 50 of Set 14 | jacksonville
# Processing Record 1 of Set 15 | sinnamary
# Processing Record 2 of Set 15 | bassar
# Processing Record 3 of Set 15 | sobolevo
# Processing Record 4 of Set 15 | erdenet
# Processing Record 5 of Set 15 | pochutla
# Processing Record 6 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 7 of Set 15 | talnakh
# Processing Record 8 of Set 15 | fairbanks
# Processing Record 9 of Set 15 | lensk
# Processing Record 10 of Set 15 | nkhotakota
# Processing Record 11 of Set 15 | isangel
# Processing Record 12 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 13 of Set 15 | itum-kale
# Processing Record 14 of Set 15 | port said
# Processing Record 15 of Set 15 | finschhafen
# Processing Record 16 of Set 15 | sonoita
# Processing Record 17 of Set 15 | awbari
# Processing Record 18 of Set 15 | port-gentil
# Processing Record 19 of Set 15 | rauma
# Processing Record 20 of Set 15 | ayan
# Processing Record 21 of Set 15 | pyaozerskiy
# Processing Record 22 of Set 15 | ostrovnoy
# Processing Record 23 of Set 15 | lima
# Processing Record 24 of Set 15 | columbia
# Processing Record 25 of Set 15 | leninskoye
# Processing Record 26 of Set 15 | acapulco
# Processing Record 27 of Set 15 | sabancuy
# Processing Record 28 of Set 15 | hamilton
# Processing Record 29 of Set 15 | honiara
# Processing Record 30 of Set 15 | sokoto
# Processing Record 31 of Set 15 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 15 | southbridge
# Processing Record 33 of Set 15 | bukachacha
# Processing Record 34 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 15 | sayyan
# Processing Record 36 of Set 15 | puerto penasco
# Processing Record 37 of Set 15 | shu
# Processing Record 38 of Set 15 | kuytun
# Processing Record 39 of Set 15 | umm lajj
# Processing Record 40 of Set 15 | paldiski
# Processing Record 41 of Set 15 | samoylovka
# Processing Record 42 of Set 15 | bentiu
# Processing Record 43 of Set 15 | mollendo
# Processing Record 44 of Set 15 | rioja
# Processing Record 45 of Set 15 | anloga
# Processing Record 46 of Set 15 | constitucion
# Processing Record 47 of Set 15 | makaleng
# Processing Record 48 of Set 15 | kyra
# Processing Record 49 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 15 | saint-joseph
# Processing Record 1 of Set 16 | kushiro
# Processing Record 2 of Set 16 | bintulu
# Processing Record 3 of Set 16 | plainview
# Processing Record 4 of Set 16 | alofi
# Processing Record 5 of Set 16 | cradock
# Processing Record 6 of Set 16 | freetown
# Processing Record 7 of Set 16 | berlevag
# Processing Record 8 of Set 16 | kutum
# Processing Record 9 of Set 16 | isla vista
# Processing Record 10 of Set 16 | xuddur
# Processing Record 11 of Set 16 | cah ab
# City not found. Skipping...
# Processing Record 12 of Set 16 | saint-paul
# Processing Record 13 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 16 | bonthe
# Processing Record 15 of Set 16 | kaniama
# Processing Record 16 of Set 16 | cam ranh
# Processing Record 17 of Set 16 | pascagoula
# Processing Record 18 of Set 16 | khani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Xuanhua      CN  40.6103  115.0447     71.44        68          22
# 1       Riyadh      SA  24.6877   46.7219    102.34         9          19
# 2        Craig      US  40.5153 -107.5464     67.95        30           0
# 3        Kindu      CD  -2.9500   25.9500     80.67        57          87
# 4      Kismayo      SO  -0.3582   42.5454     78.39        83          29
# 5   Nikolskoye      RU  59.7035   30.7861     64.29        59          57
# 6       Lompoc      US  34.6391 -120.4579     77.85        69           0
# 7  Yellowknife      CA  62.4560 -114.3525     52.32        71          75
# 8     Hermanus      ZA -34.4187   19.2345     56.80        56         100
# 9     Tasiilaq      GL  65.6145  -37.6368     37.56        95         100
#
#    Wind Speed Current Description
# 0        5.17          few clouds
# 1       10.54          few clouds
# 2        5.75           clear sky
# 3        3.00     overcast clouds
# 4       12.24          light rain
# 5        8.28       broken clouds
# 6        0.00           clear sky
# 7       12.66       broken clouds
# 8        7.81     overcast clouds
# 9        2.08     overcast clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the City_data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
